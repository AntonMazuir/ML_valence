# %%
import os
import json
import pandas as pd
from pathlib import Path

# On remonte d'un niveau pour atteindre la racine du projet
root_dir = Path(os.getcwd()).parent
data_dir = root_dir / "data" / "raw"

# On cherche le fichier le plus récent
list_of_files = list(data_dir.glob('*.json'))
if list_of_files:
    latest_file = max(list_of_files, key=os.path.getctime)
    print(f"📂 Chargement de : {latest_file.name}")

    with open(latest_file, "r", encoding="utf-8") as f:
        data = json.load(f)

    df = pd.DataFrame(data['elementList'])
    print(f"✅ DataFrame créé : {len(df)} annonces.")
else:
    print("❌ Aucun fichier trouvé. Vérifie le chemin !")
# Out:
# 📂 Chargement de : valence_20251224_011917.json
# ✅ DataFrame créé : 50 annonces.

# %%
df.head()
# Out:
#   propertyCode                                          thumbnail  \
# 0    109790346  https://img4.idealista.com/blur/480_360_mq/0/i...
# 1    109062925  https://img4.idealista.com/blur/480_360_mq/0/i...
# 2    107054487  https://img4.idealista.com/blur/480_360_mq/0/i...
# 3     90628380  https://img4.idealista.com/blur/480_360_mq/0/i...
# 4    104743376  https://img4.idealista.com/blur/480_360_mq/0/i...
#
#   externalReference  numPhotos floor      price  \
# 0          W-030F7C         68     2   615000.0
# 1         LCGV-1442         32     2   665000.0
# 2          W-02Y93Q         41     4   465000.0
# 3          W-02DX9J         44     1  1650000.0
# 4          W-02VB84         37     3  1300000.0
#
#                                            priceInfo propertyType operation  \
# 0  {'price': {'amount': 615000.0, 'currencySuffix...         flat      sale
# 1  {'price': {'amount': 665000.0, 'currencySuffix...         flat      sale
# ...

# %%
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
# 1. Quelles colonnes sont exploitables ?
print(df.columns)

# 2. Y a-t-il beaucoup de données manquantes ?
print(df.isnull().sum())

# 3. Aperçu rapide de la relation Prix / Surface (la base de tout)

plt.scatter(df['size'], df['price'])
plt.xlabel('Surface (m2)')
plt.ylabel('Prix (€)')
plt.title('Distribution des prix à Valence')
plt.show()
# Out:
# Index(['propertyCode', 'thumbnail', 'externalReference', 'numPhotos', 'floor',
#        'price', 'priceInfo', 'propertyType', 'operation', 'size', 'exterior',
#        'rooms', 'bathrooms', 'address', 'province', 'municipality', 'district',
#        'country', 'neighborhood', 'latitude', 'longitude', 'showAddress',
#        'url', 'distance', 'description', 'hasVideo', 'status',
#        'newDevelopment', 'hasLift', 'priceByArea', 'change', 'detailedType',
#        'suggestedTexts', 'hasPlan', 'has3DTour', 'has360', 'hasStaging',
#        'highlight', 'savedAd', 'notes', 'topNewDevelopment',
#        'newDevelopmentHighlight', 'topPlus', 'parkingSpace'],
#       dtype='object')
# propertyCode                0
# thumbnail                   0
# externalReference           0
# numPhotos                   0
# floor                       2
# price                       0
# priceInfo                   0
# propertyType                0
# operation                   0
# ...

# %%
import pandas as pd
df = pd.read_csv('data/processed/valence_training_set.csv')

# Est-ce que le prix moyen change selon le quartier ?
print(df.groupby('district')['price_per_m2'].mean().sort_values(ascending=False))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 2
#       1 import pandas as pd
# ----> 2 df = pd.read_csv('data/processed/valence_training_set.csv')
#       4 # Est-ce que le prix moyen change selon le quartier ?
#       5 print(df.groupby('district')['price_per_m2'].mean().sort_values(ascending=False))
#
# ...
